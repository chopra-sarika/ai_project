# %%
import csv

with open('car_index.csv', mode='r') as infile:
    reader = csv.reader(infile)
    brand_dict = {rows[0]:int(rows[1]) for rows in reader}

with open('car_price.csv', mode='r') as infile:
    reader = csv.reader(infile)
    model_dict = {rows[0]:int(rows[1]) for rows in reader}


year_n = int(input("Enter year of the car in which purchased:-"))
brand_n = input("Enter car brand:-")
model_n = input("Enter model of the car:-")
kms_n = int(input("Kilometers driven:-"))
hand_n = int(input("Hand:-"))




def brand_index(brand, model, hand):
    global value_brand
    global value_model
    global brand_value_cost_cut

    for br in brand_dict:
        if br == brand:
            value_brand = brand_dict[br]

    if 1 <= value_brand <= 3:

        for pr in model_dict:
            if pr == model:
                value_model = model_dict[pr]

        if 2000000 >= value_model >= 1500000:

            if hand == 1:
                brand_value_cost_cut = 200000
            elif hand == 2:
                brand_value_cost_cut = 150000
            elif hand == 3:
                brand_value_cost_cut = 250000
            else:
                brand_value_cost_cut = 350000

        elif 1499999 >= value_model >= 1000000:

            if hand == 1:
                brand_value_cost_cut = 140000
            elif hand == 2:
                brand_value_cost_cut = 170000
            elif hand == 3:
                brand_value_cost_cut = 230000
            else:
                brand_value_cost_cut = 300000

        elif 999999 >= value_model >= 800000:
            if hand == 1:
                brand_value_cost_cut = 120000
            elif hand == 2:
                brand_value_cost_cut = 150000
            elif hand == 3:
                brand_value_cost_cut = 200000
            else:
                brand_value_cost_cut = 250000

        elif 799999 >= value_model >= 600000:
            if hand == 1:
                brand_value_cost_cut = 100000
            elif hand == 2:
                brand_value_cost_cut = 120000
            elif hand == 3:
                brand_value_cost_cut = 180000
            else:
                brand_value_cost_cut = 230000

        elif 599999 >= value_model >= 300000:

            if hand == 1:
                brand_value_cost_cut = 60000
            elif hand == 2:
                brand_value_cost_cut = 100000
            elif hand == 3:
                brand_value_cost_cut = 150000
            else:
                brand_value_cost_cut = 200000

        elif 299999 >= value_model >= 100000:
            if hand == 1:
                brand_value_cost_cut = 25000
            else:
                brand_value_cost_cut = 50000

        else:
            brand_value_cost_cut = 10000

    elif 4 <= value_brand <= 5:

        for pr in model_dict:
            if pr == model:
                value_model = model_dict[pr]

        if 200000 >= value_model >= 1500000:

            if hand == 1:
                brand_value_cost_cut = 300000
            elif hand == 2:
                brand_value_cost_cut = 250000
            elif hand == 3:
                brand_value_cost_cut = 350000
            else:
                brand_value_cost_cut = 450000

        elif 1499999 >= value_model >= 1000000:

            if hand == 1:
                brand_value_cost_cut = 200000
            elif hand == 2:
                brand_value_cost_cut = 230000
            elif hand == 3:
                brand_value_cost_cut = 280000
            else:
                brand_value_cost_cut = 320000

        elif 999999 >= value_model >= 800000:
            if hand == 1:
                brand_value_cost_cut = 180000
            elif hand == 2:
                brand_value_cost_cut = 220000
            elif hand == 3:
                brand_value_cost_cut = 260000
            else:
                brand_value_cost_cut = 300000

        elif 799999 >= value_model >= 600000:
            if hand == 1:
                brand_value_cost_cut = 130000
            elif hand == 2:
                brand_value_cost_cut = 170000
            elif hand == 3:
                brand_value_cost_cut = 210000
            else:
                brand_value_cost_cut = 280000

        elif 599999 >= value_model >= 300000:

            if hand == 1:
                brand_value_cost_cut = 90000
            elif hand == 2:
                brand_value_cost_cut = 120000
            elif hand == 3:
                brand_value_cost_cut = 160000
            else:
                brand_value_cost_cut = 200000

        elif 299999 >= value_model >= 100000:
            if hand == 1:
                brand_value_cost_cut = 25000
            else:
                brand_value_cost_cut = 50000

        else:
            brand_value_cost_cut = 10000

    return brand_value_cost_cut


def age_index(year, kms, hand):
    global age_value_cost_cut
    if year == 2020:
        if 0 <= kms <= 10000:
            if hand == 1:
                age_value_cost_cut = 2000
            elif hand == 2:
                age_value_cost_cut = 4000
            else:
                age_value_cost_cut = 5000

        elif 10000 < kms <= 20000:
            if hand == 1:
                age_value_cost_cut = 4000
            elif hand == 2:
                age_value_cost_cut = 6000
            else:
                age_value_cost_cut = 8000

        elif 20000 < kms <= 50000:
            if hand == 1:
                age_value_cost_cut = 8000
            elif hand == 2:
                age_value_cost_cut = 12000
            else:
                age_value_cost_cut = 16000

        else:
            if hand == 1:
                age_value_cost_cut = 16000
            elif hand == 2:
                age_value_cost_cut = 24000
            else:
                age_value_cost_cut = 32000

    elif year == 2019 or year == 2018:

        if 0 <= kms <= 10000:
            if hand == 1:
                age_value_cost_cut = 3000
            elif hand == 2:
                age_value_cost_cut = 5000
            else:
                age_value_cost_cut = 6000

        elif 10000 < kms <= 20000:
            if hand == 1:
                age_value_cost_cut = 5000
            elif hand == 2:
                age_value_cost_cut = 7000
            else:
                age_value_cost_cut = 9000

        elif 20000 < kms <= 50000:
            if hand == 1:
                age_value_cost_cut = 10000
            elif hand == 2:
                age_value_cost_cut = 14000
            else:
                age_value_cost_cut = 18000

        else:
            if hand == 1:
                age_value_cost_cut = 18000
            elif hand == 2:
                age_value_cost_cut = 26000
            else:
                age_value_cost_cut = 34000

    elif year == 2017 or year == 2016:

        if 0 <= kms <= 10000:
            if hand == 1:
                age_value_cost_cut = 4000
            elif hand == 2:
                age_value_cost_cut = 6000
            else:
                age_value_cost_cut = 7000

        elif 10000 < kms <= 20000:
            if hand == 1:
                age_value_cost_cut = 6000
            elif hand == 2:
                age_value_cost_cut = 8000
            else:
                age_value_cost_cut = 10000

        elif 20000 < kms <= 50000:
            if hand == 1:
                age_value_cost_cut = 10000
            elif hand == 2:
                age_value_cost_cut = 14000
            else:
                age_value_cost_cut = 18000

        else:
            if hand == 1:
                age_value_cost_cut = 20000
            elif hand == 2:
                age_value_cost_cut = 28000
            else:
                age_value_cost_cut = 36000

    else:

        if 0 <= kms <= 10000:
            if hand == 1:
                age_value_cost_cut = 6000
            elif hand == 2:
                age_value_cost_cut = 8000
            else:
                age_value_cost_cut = 9000

        elif 10000 < kms <= 20000:
            if hand == 1:
                age_value_cost_cut = 8000
            elif hand == 2:
                age_value_cost_cut = 10000
            else:
                age_value_cost_cut = 12000

        elif 20000 < kms <= 50000:
            if hand == 1:
                age_value_cost_cut = 14000
            elif hand == 2:
                age_value_cost_cut = 18000
            else:
                age_value_cost_cut = 20000

        else:
            if hand == 1:
                age_value_cost_cut = 24000
            elif hand == 2:
                age_value_cost_cut = 30000
            else:
                age_value_cost_cut = 38000

    return age_value_cost_cut


def cost_calculation():
    global value
    brand_value = brand_index(brand_n, model_n, hand_n)
    age_value = age_index(year_n, kms_n, hand_n)

    for pr in model_dict:
        if pr == model_n:
            value = model_dict[pr]

    print(value-brand_value - age_value)


cost_calculation()
# Out:
# Enter year of the car in which purchased:-2015
# Enter car brand:-renault
# Enter model of the car:-duster
# Kilometers driven:-30000
# Hand:-2
# 648000
